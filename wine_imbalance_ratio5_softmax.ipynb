# %%
import warnings 
warnings.filterwarnings(action='ignore')

import pandas as pd 
import numpy as np 
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import ParameterGrid 
from sklearn.model_selection import KFold 
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score 
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier as LGBMC 
from lightgbm.sklearn import LGBMRegressor
from imblearn.over_sampling import SMOTE 
from imblearn.combine import SMOTETomek 
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks 
from imblearn.under_sampling import NearMiss 
from imblearn.over_sampling import ADASYN 

import matplotlib.pyplot as plt 
from tqdm import tqdm
from sklearn.model_selection import GridSearchCV
from tqdm import tqdm

# %%
train_data=pd.read_csv('/dshome/WoongLab/heo/imbalance_wine/dataset/train_wine.csv')
val_data=pd.read_csv('/dshome/WoongLab/heo/imbalance_wine/dataset/val_wine.csv')
test_data=pd.read_csv('/dshome/WoongLab/heo/imbalance_wine/dataset/test_wine.csv')

# %%
train_data['quality'].value_counts()
# Out:
# 0    655
# 1    544
# Name: quality, dtype: int64

# %%
655*(1/5)
# Out:
# 131.0

# %%
train_data_good=train_data[train_data['quality']==0]
train_data_bad=train_data[train_data['quality']==1]
train_data_bad_sample=train_data_bad.sample(131,replace=False,random_state=42)

# %%
train_data=pd.concat([train_data_good,train_data_bad_sample])

# %%
train_data_features=train_data.drop(['quality'],axis=1)
train_data_label=train_data['quality']

# %%
val_data_features=val_data.drop(['quality'],axis=1)
val_data_label=val_data['quality']

# %%
test_data_features=test_data.drop(['quality'],axis=1)
test_data_label=test_data['quality']

# %% [markdown]
# ## **Baseline Model & Teacher Model -- LightgbmClassifier 구축**

# %%
lgbc_case1=LGBMC(n_estimators=200, max_depth=5, random_state=42)
lgbc_case2=LGBMC(n_estimators=500, max_depth=5, random_state=42)
lgbc_case3=LGBMC(n_estimators=1000, max_depth=5, random_state=42)
lgbc_case4=LGBMC(n_estimators=200, max_depth=7, random_state=42)
lgbc_case5=LGBMC(n_estimators=500, max_depth=7, random_state=42)
lgbc_case6=LGBMC(n_estimators=1000, max_depth=7, random_state=42)

# %%
lgbc_case1.fit(train_data_features,train_data_label)
lgbc_case2.fit(train_data_features,train_data_label)
lgbc_case3.fit(train_data_features,train_data_label)
lgbc_case4.fit(train_data_features,train_data_label)
lgbc_case5.fit(train_data_features,train_data_label)
lgbc_case6.fit(train_data_features,train_data_label)
# Out:
# LGBMClassifier(max_depth=7, n_estimators=1000, random_state=42)

# %%
from sklearn.metrics import roc_auc_score

def get_clf_eval(y_test,pred):
    confusion=confusion_matrix(y_test,pred)
    accuracy=accuracy_score(y_test,pred)
    precision=precision_score(y_test,pred)
    recall=recall_score(y_test,pred)
    # F1 스코어 추가
    f1=f1_score(y_test,pred,average='macro')
    AUC_score=roc_auc_score(y_test,pred)
    print('임계값: ', 0.5) 
    print('오차행렬')
    print(confusion) 
    #f1 score print 추가 
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy,precision,recall,f1,AUC_score))

# %%
# learning_rate=0.01, max_depth=5, n_estimators=500, num_leaves=30,

pred_val_case1=lgbc_case1.predict(val_data_features)
pred_val_case2=lgbc_case2.predict(val_data_features)
pred_val_case3=lgbc_case3.predict(val_data_features)
pred_val_case4=lgbc_case4.predict(val_data_features)
pred_val_case5=lgbc_case5.predict(val_data_features)
pred_val_case6=lgbc_case6.predict(val_data_features)

# %%
# max_depth=5, n_estimators=200일 때 

get_clf_eval(val_data_label,pred_val_case1)
# Out:
# 임계값:  0.5
# 오차행렬
# [[95  5]
#  [69 31]]
# 정확도: 0.6300, 정밀도: 0.8611, 재현율: 0.3100, F1:0.5878, AUC:0.6300

# %%
# max_depth=5, n_estimators=500일 때 

get_clf_eval(val_data_label,pred_val_case2)
# Out:
# 임계값:  0.5
# 오차행렬
# [[95  5]
#  [64 36]]
# 정확도: 0.6550, 정밀도: 0.8780, 재현율: 0.3600, F1:0.6221, AUC:0.6550

# %%
# max_depth=5, n_estimators=1000일 때 

get_clf_eval(val_data_label,pred_val_case3)
# Out:
# 임계값:  0.5
# 오차행렬
# [[95  5]
#  [68 32]]
# 정확도: 0.6350, 정밀도: 0.8649, 재현율: 0.3200, F1:0.5948, AUC:0.6350

# %%
# max_depth=7, n_estimators=200일 때 

get_clf_eval(val_data_label,pred_val_case4)
# Out:
# 임계값:  0.5
# 오차행렬
# [[95  5]
#  [75 25]]
# 정확도: 0.6000, 정밀도: 0.8333, 재현율: 0.2500, F1:0.5442, AUC:0.6000

# %%
# max_depth=7, n_estimators=500일 때 

get_clf_eval(val_data_label,pred_val_case5)
# Out:
# 임계값:  0.5
# 오차행렬
# [[94  6]
#  [70 30]]
# 정확도: 0.6200, 정밀도: 0.8333, 재현율: 0.3000, F1:0.5766, AUC:0.6200

# %%
# max_depth=7, n_estimators=1000일 때 

get_clf_eval(val_data_label,pred_val_case6)
# Out:
# 임계값:  0.5
# 오차행렬
# [[93  7]
#  [68 32]]
# 정확도: 0.6250, 정밀도: 0.8205, 재현율: 0.3200, F1:0.5865, AUC:0.6250

# %% [markdown]
# #### Teacher Model parameter는 max_depth=5, n_estimators=500
#
# #### Student Model parameter는 max_depth=7, n_estimators=200

# %%
lgbc_teacher=LGBMC(n_estimators=500, max_depth=5, random_state=42)

lgbreg_student=LGBMRegressor(n_estimators=200, max_depth=7, random_state=42)

lgbc_notdistilled_student=LGBMC(n_estimators=200, max_depth=7, random_state=42)

# %%
lgbc_teacher.fit(train_data_features,train_data_label)
# Out:
# LGBMClassifier(max_depth=5, n_estimators=500, random_state=42)

# %%
#  train_new_probab 데이터프레임에 저장하기

train_new_probab=pd.DataFrame()
train_new_probab['Prob1']=lgbc_teacher.predict_proba(train_data_features)[:,0]
train_new_probab['Prob2']=lgbc_teacher.predict_proba(train_data_features)[:,1]

# %%
train_new_probab['odds1']=train_new_probab['Prob1']/(1-train_new_probab['Prob1'])
train_new_probab['odds2']=train_new_probab['Prob2']/(1-train_new_probab['Prob2'])

# %%
import numpy as np 

train_new_probab['z1']=np.log(train_new_probab['odds1'])
train_new_probab['z2']=np.log(train_new_probab['odds2'])

# %%
#train_new_probab['temp_z1']=np.log(train_new_probab['odds1'])/100
#train_new_probab['temp_z2']=np.log(train_new_probab['odds2'])/100

# %%
#train_new_probab['max_z']=np.where(train_new_probab['temp_z1']>train_new_probab['temp_z2'],train_new_probab['temp_z1'],train_new_probab['temp_z2'])

# %%
#train_new_probab['exp_before_z']=train_new_probab['temp_z2']-train_new_probab['max_z']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

# Student Model 평가할 함수 만들기

def get_reg_prob(y_test, probability):
  pred=np.where(probability > 0.5,1,0)
  confusion=confusion_matrix(y_test, pred)
  accuracy=accuracy_score(y_test,pred)
  precision=precision_score(y_test,pred) 
  recall=recall_score(y_test,pred) 
  # F1 스코어 추가 
  f1=f1_score(y_test,pred, average='macro')
  Roc_score=roc_auc_score(y_test,pred)
  print('임계값: ', 0.5) 
  print('오차행렬')
  print(confusion) 
  # f1 score print 추가 
  print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4: .4f}'.format(accuracy,precision,recall,f1,Roc_score))

# %%
accuracy_list=[]
precision_list=[]
recall_list=[]
f1_list=[]
roc_score_list=[]
a=list(range(1,101,1))
for temperature in a:
    train_new_probab['temp_z1']=np.log(train_new_probab['odds1'])/temperature
    train_new_probab['temp_z2']=np.log(train_new_probab['odds2'])/temperature
    #train_new_probab['exp_before_z']=train_new_probab['temp_z2']-train_new_probab['max_z']
    train_new_probab['temp_prob']=np.exp(train_new_probab['temp_z2'])/(np.exp(train_new_probab['temp_z1'])+np.exp(train_new_probab['temp_z2']))
    train_new_probab['temp_prob_new']=np.where(train_new_probab['Prob2']>0.5,train_new_probab['Prob2'],train_new_probab['temp_prob'])
    lgbreg_student.fit(train_data_features,train_new_probab['temp_prob_new'])
    probab1=lgbreg_student.predict(val_data_features)
    pred=np.where(probab1 > 0.5,1,0)
    confusion=confusion_matrix(val_data_label, pred)
    accuracy=accuracy_score(val_data_label,pred)
    precision=precision_score(val_data_label, pred) 
    recall=recall_score(val_data_label, pred) 
    f1=f1_score(val_data_label, pred, average='macro')
    Roc_score=roc_auc_score(val_data_label, pred)
    print('temperature가 {}일 때의 validation set 평가 결과입니다.'.format(temperature))
    print('오차행렬')
    print(confusion)
    accuracy_list.append(accuracy)
    precision_list.append(precision)
    recall_list.append(recall)
    f1_list.append(f1)
    roc_score_list.append(Roc_score)
# Out:
# temperature가 1일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[93  7]
#  [68 32]]
# temperature가 2일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[91  9]
#  [66 34]]
# temperature가 3일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[89 11]
#  [63 37]]
# temperature가 4일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[93  7]
#  [64 36]]
# temperature가 5일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[88 12]
#  [65 35]]
# temperature가 6일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[86 14]
#  [57 43]]
# temperature가 7일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[89 11]
#  [55 45]]
# temperature가 8일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[86 14]
#  [46 54]]
# temperature가 9일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[85 15]
#  [49 51]]
# temperature가 10일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[82 18]
#  [50 50]]
# temperature가 11일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[86 14]
#  [51 49]]
# temperature가 12일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[83 17]
#  [41 59]]
# temperature가 13일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[82 18]
#  [39 61]]
# temperature가 14일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[83 17]
#  [41 59]]
# temperature가 15일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[78 22]
#  [40 60]]
# temperature가 16일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[77 23]
#  [36 64]]
# temperature가 17일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[79 21]
#  [31 69]]
# temperature가 18일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[80 20]
#  [33 67]]
# temperature가 19일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[78 22]
#  [27 73]]
# temperature가 20일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[78 22]
#  [26 74]]
# temperature가 21일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[77 23]
#  [24 76]]
# temperature가 22일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[73 27]
#  [23 77]]
# temperature가 23일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[76 24]
#  [29 71]]
# temperature가 24일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[74 26]
#  [23 77]]
# temperature가 25일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[76 24]
#  [22 78]]
# temperature가 26일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[74 26]
#  [22 78]]
# temperature가 27일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[74 26]
#  [19 81]]
# temperature가 28일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[71 29]
#  [20 80]]
# temperature가 29일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[70 30]
#  [19 81]]
# temperature가 30일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[71 29]
#  [17 83]]
# temperature가 31일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[74 26]
#  [19 81]]
# temperature가 32일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[71 29]
#  [18 82]]
# temperature가 33일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[70 30]
#  [17 83]]
# temperature가 34일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[72 28]
#  [14 86]]
# temperature가 35일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[69 31]
#  [14 86]]
# temperature가 36일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[70 30]
#  [15 85]]
# temperature가 37일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[69 31]
#  [17 83]]
# temperature가 38일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[68 32]
#  [22 78]]
# temperature가 39일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[70 30]
#  [17 83]]
# temperature가 40일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[69 31]
#  [17 83]]
# temperature가 41일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[67 33]
#  [14 86]]
# temperature가 42일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[67 33]
#  [14 86]]
# temperature가 43일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[67 33]
#  [11 89]]
# temperature가 44일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[67 33]
#  [12 88]]
# temperature가 45일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [12 88]]
# temperature가 46일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[64 36]
#  [14 86]]
# temperature가 47일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[67 33]
#  [13 87]]
# temperature가 48일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[63 37]
#  [15 85]]
# temperature가 49일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [10 90]]
# temperature가 50일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[63 37]
#  [11 89]]
# temperature가 51일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[66 34]
#  [13 87]]
# temperature가 52일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [11 89]]
# temperature가 53일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [ 9 91]]
# temperature가 54일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[63 37]
#  [10 90]]
# temperature가 55일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [10 90]]
# temperature가 56일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [12 88]]
# temperature가 57일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [12 88]]
# temperature가 58일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [11 89]]
# temperature가 59일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 9 91]]
# temperature가 60일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [12 88]]
# temperature가 61일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [11 89]]
# temperature가 62일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [ 9 91]]
# temperature가 63일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[63 37]
#  [11 89]]
# temperature가 64일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [ 9 91]]
# temperature가 65일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 9 91]]
# temperature가 66일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [11 89]]
# temperature가 67일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [11 89]]
# temperature가 68일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [ 7 93]]
# temperature가 69일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[65 35]
#  [10 90]]
# temperature가 70일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[62 38]
#  [11 89]]
# temperature가 71일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 8 92]]
# temperature가 72일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [ 8 92]]
# temperature가 73일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[63 37]
#  [ 9 91]]
# temperature가 74일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [ 8 92]]
# temperature가 75일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[64 36]
#  [10 90]]
# temperature가 76일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[64 36]
#  [ 9 91]]
# temperature가 77일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[56 44]
#  [10 90]]
# temperature가 78일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[57 43]
#  [ 8 92]]
# temperature가 79일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 8 92]]
# temperature가 80일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [11 89]]
# temperature가 81일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[61 39]
#  [10 90]]
# temperature가 82일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[64 36]
#  [ 9 91]]
# temperature가 83일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 9 91]]
# temperature가 84일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 8 92]]
# temperature가 85일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[58 42]
#  [ 8 92]]
# temperature가 86일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [11 89]]
# temperature가 87일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [ 8 92]]
# temperature가 88일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 8 92]]
# temperature가 89일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[53 47]
#  [ 8 92]]
# temperature가 90일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[57 43]
#  [ 7 93]]
# temperature가 91일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[53 47]
#  [ 8 92]]
# temperature가 92일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[60 40]
#  [ 9 91]]
# temperature가 93일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[56 44]
#  [ 9 91]]
# temperature가 94일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[58 42]
#  [ 9 91]]
# temperature가 95일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[53 47]
#  [10 90]]
# temperature가 96일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[55 45]
#  [ 8 92]]
# temperature가 97일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [ 8 92]]
# temperature가 98일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [11 89]]
# temperature가 99일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[57 43]
#  [ 9 91]]
# temperature가 100일 때의 validation set 평가 결과입니다.
# 오차행렬
# [[59 41]
#  [11 89]]

# %%
import matplotlib.pyplot as plt 
a=list(range(1,101,1))
plt.figure(figsize=(25,10))
plt.plot(a,accuracy_list)
plt.xlabel('Temperature') 
plt.ylabel('Accuracy')
plt.xticks(range(1,101,1),size=12,rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt 
a=list(range(1,101,1))
plt.figure(figsize=(25,10))
plt.plot(a,f1_list)
plt.xlabel('Temperature') 
plt.ylabel('F-1 Score')
plt.xticks(range(1,101,1),size=12,rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt 
a=list(range(1,101,1))
plt.figure(figsize=(25,10))
plt.plot(a,roc_score_list)
plt.xlabel('Temperature') 
plt.ylabel('AUC-1 Score')
plt.xticks(range(1,101,1),size=12,rotation=90)
plt.show()

# %%
temperature=34
train_new_probab['temp_z1']=np.log(train_new_probab['odds1'])/temperature
train_new_probab['temp_z2']=np.log(train_new_probab['odds2'])/temperature
# train_new_probab['max_z']=np.where(train_new_probab['temp_z1']>train_new_probab['temp_z2'],train_new_probab['temp_z1'],train_new_probab['temp_z2'])
# train_new_probab['exp_before_z']=train_new_probab['temp_z2']-train_new_probab['max_z']
train_new_probab['temp_prob']=np.exp(train_new_probab['temp_z2'])/(np.exp(train_new_probab['temp_z1'])+np.exp(train_new_probab['temp_z2']))
train_new_probab['temp_prob_new']=np.where(train_new_probab['Prob2']>0.5,train_new_probab['Prob2'],train_new_probab['temp_prob'])

# %%
lgbreg_student.fit(train_data_features,train_new_probab['temp_prob_new'])
# Out:
# LGBMRegressor(max_depth=7, n_estimators=200, random_state=42)

# %%
probab1=lgbreg_student.predict(test_data_features)

# %%
get_reg_prob(test_data_label, probab1)
# Out:
# 임계값:  0.5
# 오차행렬
# [[74 26]
#  [31 69]]
# 정확도: 0.7150, 정밀도: 0.7263, 재현율: 0.6900, F1:0.7148, AUC: 0.7150

# %% [markdown]
# ## not distilled test data evaluation

# %%
lgbc_notdistilled_student.fit(train_data_features,train_data_label)
# Out:
# LGBMClassifier(max_depth=7, n_estimators=200, random_state=42)

# %%
pred2=lgbc_notdistilled_student.predict(test_data_features)

# %%
get_clf_eval(test_data_label,pred2)
# Out:
# 임계값:  0.5
# 오차행렬
# [[93  7]
#  [68 32]]
# 정확도: 0.6250, 정밀도: 0.8205, 재현율: 0.3200, F1:0.5865, AUC:0.6250
